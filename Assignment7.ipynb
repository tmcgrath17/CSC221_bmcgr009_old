# %% [markdown]
# <a href="https://colab.research.google.com/github/tmcgrath17/CSC221_bmcgr009/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Brady McGrath
#Assignment 7

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0['color'])
print(alien_0['points'])

new_points = alien_0['points']
print(f"You just earned {new_points} points!")

print(f"The alien is {alien_0['color']}.")
alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")

alien_0 = {'x_position': 0, 'y_position': 25, 'speed': 'medium'}
print(f"Original position: {alien_0['x_position']}")
if alien_0['speed'] == 'slow':
 x_increment = 1
elif alien_0['speed'] == 'medium':
 x_increment = 2
else:
 x_increment = 3
alien_0['x_position'] = alien_0['x_position'] + x_increment
print(f"New position: {alien_0['x_position']}")
alien_0['speed'] = 'fast'

alien_0 = {'color': 'green', 'points': 5}
print(alien_0)
del alien_0['points']
print(alien_0)

alien_0 = {'color': 'green', 'speed': 'slow'}
point_value = alien_0.get('points', 'No point value assigned.')
print(point_value)

#Try It Yourself

katie = {'first_name': 'Katie', 'last_name': 'Hosier', 'age': 18, 'city': 'Saratoga'}
print(katie['first_name'])
print(katie['last_name'])
print(katie['age'])
print(katie['city'])

fav_numbers = {
    'katie': 7,
    'dylan': 11,
    'lily': 2,
    'eliana': 21,
    'ella': 13
}

print(f"Katie's favorite number is {fav_numbers['katie']}!")
print(f"Dylan's favorite number is {fav_numbers['dylan']}!")
print(f"Lily's favorite number is {fav_numbers['lily']}!")
print(f"Eliana's favorite number is {fav_numbers['eliana']}!")
print(f"Ella's favorite number is {fav_numbers['ella']}!")

glossary = {
    'variable': 'a term that represents a declared piece of data.',
    'concatenate': 'to link together in a chain or series.',
    'runtime': 'stage where the program is running alongside external execution instructions.',
    'conditional': 'subject to one or more conditions or requirements being met.',
    'argument': "a value passed to obtain the function's result.",
    'function': 'code that can be referenced by name to run the code it contains.',
    'input': 'interaction from the user used in the program.',
    'loop': 'a section of code that is repeated continuously until a defined condition is met.',
    'algorithm': 'a set of instructions or equations that are followed to process a specific request.',
    'file': 'a resource for recording data, such as code, on a storage device.'
}

for term in sorted(glossary.keys()):
  print(f"\n{term.title()}: {glossary[term]}")

# %%
favorite_languages = {
 'jen': 'python',
 'sarah': 'c',
 'edward': 'rust',
 'phil': 'python',
}

language = favorite_languages['sarah'].title()
print(f"Sarah's favorite language is {language}.")

for name, language in favorite_languages.items():
 print(f"{name.title()}'s favorite language is {language.title()}.")

friends = ['phil', 'sarah']
for name in favorite_languages.keys():
 print(f"Hi {name.title()}.")

 if name in friends:
  language = favorite_languages[name].title()
  print(f"\t{name.title()}, I see you love {language}!")

if 'erin' not in favorite_languages.keys():
 print("Erin, please take our poll!")

for name in sorted(favorite_languages.keys()):
 print(f"{name.title()}, thank you for taking the poll.")

print("The following languages have been mentioned:")
for language in set(favorite_languages.values()):
 print(language.title())

# %%
user_0 = {
 'username': 'efermi',
 'first': 'enrico',
 'last': 'fermi',
 }

for key, value in user_0.items():
 print(f"\nKey: {key}")
 print(f"Value: {value}")

# %%
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}
aliens = [alien_0, alien_1, alien_2]
for alien in aliens:
 print(alien)

aliens = []
for alien_number in range(30):
  new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
  aliens.append(new_alien)

for alien in aliens[:3]:
  if alien['color'] == 'green':
    alien['color'] = 'yellow'
    alien['speed'] = 'medium'
    alien['points'] = 10
  elif alien['color'] == 'yellow':
    alien['color'] = 'red'
    alien['speed'] = 'fast'
    alien['points'] = 15

for alien in aliens[:5]:
 print(alien)
print("...")

print(f"Total number of aliens: {len(aliens)}")

# %%
pizza = {
 'crust': 'thick',
 'toppings': ['mushrooms', 'extra cheese'],
 }

print(f"You ordered a {pizza['crust']}-crust pizza with the following toppings:")
for topping in pizza['toppings']:
 print(f"\t{topping}")

favorite_languages = {
 'jen': ['python', 'rust'],
 'sarah': ['c'],
 'edward': ['rust', 'go'],
 'phil': ['python', 'haskell'],
 }

for name, languages in favorite_languages.items():
  print(f"\n{name.title()}'s favorite languages are:")
  for language in languages:
    print(f"\t{language.title()}")

users = {
 'aeinstein': {
 'first': 'albert',
 'last': 'einstein',
 'location': 'princeton',
 'website': 'gmail.com',
 },
 'mcurie': {
 'first': 'marie',
 'last': 'curie',
 'location': 'paris',
 'website': 'gmail.com',
 },
 'jshmoe': {
 'first': 'joe',
 'last': 'shmoe',
 'location': 'detroit',
 'website': 'joesite.com',
 },
 'tmcgrath': {
 'first': 'tiff',
 'last': 'mcgrath',
 'location': 'plattsburgh',
 'website': 'plattsburgh.edu',
 },
 'dvelducea': {
 'first': 'dylan',
 'last': 'velducea',
 'location': 'saratoga',
 'website': 'icloud.com',
 },
}
idcount = 0
for username, user_info in sorted(users.items()):
 idcount += 1
 print(f"\nUsername: {username}")
 full_name = f"{user_info['first']} {user_info['last']}"
 initials = f"{user_info['first'][0:1]}{user_info['last'][0:1]}"
 location = user_info['location']
 print(f"\tFull Name: {full_name.title()}")
 print(f"\tContact: {username}@{user_info['website']}")
 print(f"\tInitials: {initials.upper()}")
 print(f"\tUser ID: 000{str(idcount)}")
 print(f"\tLocation: {location.title()}")


#The 6-12 Try It Yourself can be seen in the users section above
# Out:
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese
#
# Jen's favorite languages are:
# 	Python
# 	Rust
#
# Sarah's favorite languages are:
# 	C
#
# Edward's favorite languages are:
# 	Rust
# 	Go
#
# Phil's favorite languages are:
# 	Python
# 	Haskell
#
# Username: aeinstein
# 	Full Name: Albert Einstein
# 	Contact: aeinstein@gmail.com
# 	Initials: AE
# 	User ID: 0001
# 	Location: Princeton
#
# Username: dvelducea
# 	Full Name: Dylan Velducea
# 	Contact: dvelducea@icloud.com
# 	Initials: DV
# 	User ID: 0002
# 	Location: Saratoga
#
# Username: jshmoe
# 	Full Name: Joe Shmoe
# 	Contact: jshmoe@joesite.com
# 	Initials: JS
# 	User ID: 0003
# 	Location: Detroit
#
# Username: mcurie
# 	Full Name: Marie Curie
# 	Contact: mcurie@gmail.com
# 	Initials: MC
# 	User ID: 0004
# 	Location: Paris
#
# Username: tmcgrath
# 	Full Name: Tiff Mcgrath
# 	Contact: tmcgrath@plattsburgh.edu
# 	Initials: TM
# 	User ID: 0005
# 	Location: Plattsburgh
